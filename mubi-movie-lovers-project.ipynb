# %% [markdown]
# # **Strategies on MUBI Platform**

# %% [markdown]
# # **1.Big Data description**

# %% [markdown]
# ***MUBI is "Netflix of independent film***
#
# - Focus on selected classic and independent art films.
# - Mubi adds a new film every day and removes an old one at the same time.That is to say, you only have 30 movies to watch at any time.
# - Mubi adopts the mode of manual film selection.

# %% [markdown]
# ***It is "big data"***
#
# - The dataset we used contains 5 tables.
#
# - The largest individual table reaches 2 GB, and it has 15.5m rows, which cannot be fully open in Excel.

# %% [markdown]
# # **2.Data Discription**

# %% [markdown]
# ***Work Flow***

# %% [markdown]
# ![image.png](attachment:35c5b55e-d34a-47c2-9928-c3b979540be4.png)

# %% [markdown]
# ***Python & Linux Data Cleaning***

# %% [markdown]
# 1. Only keeps letters, numbers and common punctuations to remove incorrect symbols (This is not caused by reading in the wrong encode)
#
#
# 2. Remove escape newline in comment column that will cause error in rows
#
#
# 3. Execute the python file by Linux on each 5 table.

# %% [markdown]
# ***Impala Data Analytics***

# %% [markdown]
# Once we tried Hive, but Hive did not give an answer back for more than 5 HOURS while Impala returns in fewer than 5 SECONDS.

# %% [markdown]
# Impala

# %% [markdown]
# 2. What have we done in Impala?
#
# Count the number of rating users of each movie;
#
# Collected the data of 7-days user retention rate;
#
# Count the number of rating each year in past 12 years;
#
# Calculated the average score for movies in each year to find Top10s;
#
# Calculated the conversion rate from non-paying users to paying users;
#
# Calculated the average number of rating on each movie;
#
# We have tried many queries, but not all of them gave back satisfactory answers.
#
# These above queries are what we considered as satisfied and provided a base of our further conclusions.

# %% [markdown]
# # **3. Problem Statement**

# %% [markdown]
# **1. To find out Movie preference of different customers**
#
# Top 10 favorite movies in Mubi of paid and unpaid users
#
# **2. To increase stickiness and activity**
#
# Under its special operation mode to M.A.U.
#
# **3. To convert customer**
#
# Unpaid to Paid Users

# %% [markdown]
# # **4.Findings**

# %% [markdown]
# ***Number of ratings in the past 12 years***
#
# The Mubi community has less passion on rating movies than before.Their attitudes seems to be more casual on rating movies. It's harmful to increase user stickness.

# %% [markdown]
# ***An Upward Trend of User Stickiness***
#
# ![image.png](attachment:34320c5e-ae45-4c1e-a8eb-88c8fc85f124.png)
#
# The retention rate of users in 30 days:
# Calculate the percentage of users reappearing in a certain period of time
#
# In recent years, the user activity of Mubi has declined,
# but the user stickiness has shown a steady growth trend in the past decade.

# %% [markdown]
# ***TOP 10 rating score - unpaird users***
#
# The color of the tree chart changes from warm to cool from top left to bottom right. This means that the film's ratings are gradually falling.
#
# The movie with the highest score was the Dark Knight Rises,and the last one was Andrel Rublev.
#
# 60% of unpaid users like action films which are about suspense and war.

# %% [markdown]
# ***Top 10 rating score - Paid Users***
#
# ![image.png](attachment:28256268-04c5-4b93-88d5-e9c0fdae76db.png)
#
# We weighted the movie's ratings and made bubbles. From the size of the bubble, it is obvious that Jeanne Dielman scored the highest and Homeland scored the lowest.
#
# And 90% of paid users like crime suspense movies.

# %% [markdown]
# Top 10 movies - ranking by population
#
# ![image.png](attachment:5e2fe845-9a30-49a5-95e8-8e2d480f8c6b.png)
#
# The top three popular movies are: Pulp Fiction, Fight Club, A Clockwork Orange.

# %% [markdown]
# ***Proposal:***
#
# > High user stickiness – Low M.A.U.
# 90% paid users like crime suspense movies, 60% unpaid users like crime suspense movies.
#
# > Keep its own strategy of serving as a small and well-selected
# Put overlapping favorite movies of both paid and unpaid users to paid exclusive.
